# %%
import numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\n\nprint('Entorno listo 🚀')

# %%
datos = pd.DataFrame({\n    'Tiempo': [1,2,3,4,5],\n    'Concentracion': [2.1, 2.5, 3.0, 3.8, 4.2]\n})\n\ndatos
